# %%
import random
import pandas as pd
from datasets import Dataset
import os 
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig
from datasets import load_dataset
import seaborn as sns
from datasets import load_dataset, load_from_disk
import numpy as np
import json

# %%
cd /mnt/home/al2644/research/projects/rlvr
# Out:
# /mnt/home/al2644/research/projects/rlvr

# %%
train_df = pd.read_parquet("./data/train/math8k/train.parquet")
test_df = pd.read_parquet("./data/train/math8k/test.parquet")

# %%
train_problem = set(train_df['prompt'].apply(lambda x: x [0]["content"]))
test_problem = set(test_df['prompt'].apply(lambda x: x [0]["content"]))

# %%
test_df
# Out:
#     data_source                                             prompt ability  \
# 0       math500  [{'content': 'A $90^\circ$ rotation around the...    math
# 1       math500  [{'content': 'We can find the $x$-intercept by...    math
# 2       math500  [{'content': 'Multiplying, we see that $6_8 \c...    math
# 3       math500  [{'content': 'Let $\bold{v} = \begin{pmatrix} ...    math
# 4       math500  [{'content': 'Since $|a| = 1,$ $a \overline{a}...    math
# ..          ...                                                ...     ...
# 495     math500  [{'content': 'The hexagon has a side length of...    math
# 496     math500  [{'content': 'We know that magnitudes of compl...    math
# 497     math500  [{'content': 'We have $\frac{7}{30}@\frac{10}{...    math
# 498     math500  [{'content': 'Let Amy's, Ben's, and Chris's ag...    math
# 499     math500  [{'content': 'By the Rational Root Theorem, th...    math
#
#                                      reward_model  \
# 0    {'ground_truth': '-2 + 7i', 'style': 'rule'}
# 1         {'ground_truth': '13', 'style': 'rule'}
# 2       {'ground_truth': '52_8', 'style': 'rule'}
# 3          {'ground_truth': '4', 'style': 'rule'}
# 4          {'ground_truth': '0', 'style': 'rule'}
# ..                                            ...
# 495       {'ground_truth': '12', 'style': 'rule'}
# 496       {'ground_truth': '16', 'style': 'rule'}
# 497       {'ground_truth': '49', 'style': 'rule'}
# 498       {'ground_truth': '10', 'style': 'rule'}
# 499        {'ground_truth': '4', 'style': 'rule'}
#
#                                             extra_info
# 0    {'difficulty': 2, 'index': 0, 'split': 'test',...
# 1    {'difficulty': 4, 'index': 1, 'split': 'test',...
# 2    {'difficulty': 3, 'index': 2, 'split': 'test',...
# 3    {'difficulty': 5, 'index': 3, 'split': 'test',...
# 4    {'difficulty': 5, 'index': 4, 'split': 'test',...
# ..                                                 ...
# 495  {'difficulty': 2, 'index': 495, 'split': 'test...
# 496  {'difficulty': 2, 'index': 496, 'split': 'test...
# 497  {'difficulty': 2, 'index': 497, 'split': 'test...
# 498  {'difficulty': 4, 'index': 498, 'split': 'test...
# 499  {'difficulty': 3, 'index': 499, 'split': 'test...
#
# [500 rows x 5 columns]

# %%
oct_train_df = pd.read_parquet("./data/train/octothink.math.8k/train.parquet")
oct_test_df = pd.read_parquet("./data/train/octothink.math.8k/test.parquet")

# %%
oct_train_problems = set(oct_train_df['prompt'].apply(lambda x: x[-1]['content']))
oct_test_problems = set(oct_test_df[oct_test_df['data_source']=='math']['prompt'].apply(lambda x: x[-1]['content']))

# %%
len(train_problem.difference(oct_problems))
# Out:
# 116

# %%
oct_test_df["prompt"][1]
# Out:
# array([{'content': 'Please reason step by step, and put your final answer within \\boxed{}.', 'role': 'system'},
#        {'content': 'Every morning Aya goes for a $9$-kilometer-long walk and stops at a coffee shop afterwards. When she walks at a constant speed of $s$ kilometers per hour, the walk takes her 4 hours, including $t$ minutes spent in the coffee shop. When she walks $s+2$ kilometers per hour, the walk takes her 2 hours and 24 minutes, including $t$ minutes spent in the coffee shop. Suppose Aya walks at $s+\\frac{1}{2}$ kilometers per hour. Find the number of minutes the walk takes her, including the $t$ minutes spent in the coffee shop.', 'role': 'user'}],
#       dtype=object)
